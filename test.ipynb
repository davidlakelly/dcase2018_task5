# %%
import matplotlib.pyplot as plt
import preprocessor

paths = "C:\\Users\\David\\Desktop\\dcase_5\\dcase2018_task5\\DCASE2018-task5-dev\\audio\\DevNode1_ex201_28.wav"

x,y,z = preprocessor.shuffler(paths,5)
temp = x.get_array_of_samples()
plt.plot(temp)
